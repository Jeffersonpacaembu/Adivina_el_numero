# %%
    cont_jogos = 0
    cont_solitario = 0
    cont_jugadores = 0
    
    def jogo():
        global cont_solitario, cont_jugadores, cont_jogos
        print("Vamos jogar?")
        
        import juego

        print("Escolha a forma de jogo:")
        print("1. Partida modo solitario")
        print("2. Partida 2 Jugadores")
        print("3. Estadística")
        print("4. Salir")

           
        modo_juego = 0
        while modo_juego <1 or modo_juego> 4:
            modo_juego = int(input())
            if modo_juego <1 or modo_juego> 4:
                print("Opção inválida, escolha um número de 1 a 4")
                
            

        print("Vamos lá")

        if modo_juego == 1:
            cont_solitario += 1
            juego.solitario ()
            
        if modo_juego == 2:
            cont_jugadores += 1
            juego.jugadores ()
            
        if modo_juego == 3:
            print(f"Quantidade de partidas:{cont_jogos}")
            print(f"Quantidade de partidas contra a máquina:{cont_solitario}")
            print(f"Quantidade de partidas contra a máquina:{cont_jugadores}")
            
            
        if modo_juego == 4:
            print("Ok, até a próxima")
            break
            
        
    while True:
        jogo()
        cont_jogos += 1
        novo_jogo = input("Deseja jogar novamente? s/n")
        
        if novo_jogo.lower() != "s":
            break

    print("Valeu, até a próxima")
    print(f"Quantidade de partidas:{cont_jogos}")
    print(f"Quantidade de partidas contra a máquina:{cont_solitario}")
    print(f"Quantidade de partidas contra a máquina:{cont_jugadores}")
# Out:
# Vamos jogar?
# Escolha a forma de jogo:
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadística
# 4. Salir
# 1
# Vamos lá
# Escolha o nível:
# 1. Fácil (20 intentos)
# 2. Medio (12 intentos)
# 3. Difícil (5 intentos)
# 3
# Tente advinhar o número entre 1 e 1000
# Intento 1 / 5
# 3
# O número é maior
# Intento 2 / 5
# 3
# O número é maior
# Intento 3 / 5
# 3
# O número é maior
# Intento 4 / 5
# 3
# O número é maior
# ÚLTIMA TENTATIVA
# 3
# Não encontrou o número =(
# O numero procurado era 397
# Deseja jogar novamente? s/ns
# Vamos jogar?
# Escolha a forma de jogo:
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadística
# 4. Salir
# 2
# Vamos lá
# Jogador 1 insira um número entre 1 e 1000:
# ········
# Jogador 2, escolha o nível:
# 1. Fácil (20 intentos)
# 2. Medio (12 intentos)
# 3. Difícil (5 intentos)
# 2
# Jogador 2, tente advinhar o número entre 1 e 1000
# Intento 1 / 12
# 2
# O número é maior
# Intento 2 / 12
# 2
# O número é maior
# Intento 3 / 12
# ...
